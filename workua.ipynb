# %%
from xml.dom.minidom import parseString
from xml.etree.ElementTree import Element, SubElement, ElementTree
from bs4 import BeautifulSoup
import dicttoxml
import requests
import re

url = 'https://www.work.ua/jobs-it/?advs=1&salaryto=9'
r=requests.get(url).text
soup=BeautifulSoup(r, 'lxml')

d=dict()
def pars():
    l=soup.find_all('div', class_ = "card card-hover card-visited wordwrap job-link js-hot-block")
    items_list = Element('items_list')
    for kll in range(len(l)):
        if kll!=11:
            l=soup.find_all('div', class_ = "card card-hover card-visited wordwrap job-link js-hot-block")
            for i in l:
                prof=i.h2.a.text
                d['job']=prof
                money=i.div.b.text.encode().decode()
                money=money.replace("\u2009", "")
                money=money.replace("\u202f", "")
                money=money.replace("\xa0грн", "")
                d['salary']=money
                company=i.find('div', class_ = "add-top-xs").span.b.text
                d['company']=company
                city=i.find('div', class_ = "add-top-xs").text.split()
                if city[-1] == 'центру':
                    k=city[-6]
                    d['city']=k
                else:
                    kk=city[-1]
                    d['city']=kk
                work = SubElement(items_list, 'work')
                work.set('id', 'element ' + str(kll))
                kll=kll+1
                job = SubElement(work, 'job')
                job.text = d['job']
                company_name = SubElement(work, 'company_name')
                company_name.text = d['company']
                salary = SubElement(work, 'salary')
                salary.set('currency', 'hrivna')
                salary.text = d['salary']
                city = SubElement(work, 'city')
                city.text = d['city']
            tree = ElementTree(items_list)
            tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
            return pars()
        else:
            return tree   

pars()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\an\lib\xml\etree\ElementTree.py in _get_writer(file_or_filename, encoding)
#     789     try:
# --> 790         write = file_or_filename.write
#     791     except AttributeError:
#
# AttributeError: 'str' object has no attribute 'write'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-446-acf8e7618380> in <module>
#      52             return tree
#      53
# ---> 54 pars()
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      48             tree = ElementTree(items_list)
#      49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
# ---> 50             return pars()
#      51         else:
#      52             return tree
#
# <ipython-input-446-acf8e7618380> in pars()
#      47                 city.text = d['city']
#      48             tree = ElementTree(items_list)
# ---> 49             tree.write('workua.xml', encoding='UTF-8', xml_declaration=True)
#      50             return pars()
#      51         else:
#
# C:\an\lib\xml\etree\ElementTree.py in write(self, file_or_filename, encoding, xml_declaration, default_namespace, method, short_empty_elements)
#     775                 serialize = _serialize[method]
#     776                 serialize(write, self._root, qnames, namespaces,
# --> 777                           short_empty_elements=short_empty_elements)
#     778
#     779     def write_c14n(self, file):
#
# C:\an\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# C:\an\lib\xml\etree\ElementTree.py in _get_writer(file_or_filename, encoding)
#     797                         errors="xmlcharrefreplace")
#     798         with file:
# --> 799             yield file.write
#     800     else:
#     801         # file_or_filename is a file-like object
#
# KeyboardInterrupt:
